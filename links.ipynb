# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %matplotlib inline

# Ignore harmless warnings 

import warnings 
warnings.filterwarnings("ignore")

# Set to display all the columns in dataset

pd.set_option("display.max_columns", None)

# %%
df1=pd.read_csv(r"C:\Users\uvsri\OneDrive\Desktop\movie_data\links.csv")
df_bk1=df1.copy()
df1.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df2=pd.read_csv(r"C:\Users\uvsri\OneDrive\Desktop\movie_data\movies.csv")
df_bk2=df2.copy()
df2.sample(10)
# Out:
#       movieId                                              title  \
# 9334   160569                   Ice Age: Collision Course (2016)
# 8373   109383        Oversimplification of Her Beauty, An (2012)
# 1601     2143                                      Legend (1985)
# 425       488                                M. Butterfly (1993)
# 3241     4381                   Closet, The (Placard, Le) (2001)
# 6994    67295  Kung Fu Panda: Secrets of the Furious Five (2008)
# 790      1033                      Fox and the Hound, The (1981)
# 9196   150604                                 Moonwalkers (2015)
# 8457   112334  Internet's Own Boy: The Story of Aaron Swartz,...
# 4661     6963                          Devil's Playground (2002)
#
#                                    genres
# 9334  Adventure|Animation|Children|Comedy
# 8373       Animation|Comedy|Drama|Romance
# 1601            Adventure|Fantasy|Romance
# 425                         Drama|Romance
# ...

# %%
df3=pd.read_csv(r"C:\Users\uvsri\OneDrive\Desktop\movie_data\ratings.csv")
df_bk3=df3.copy()
df3.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df4=pd.read_csv(r"C:\Users\uvsri\OneDrive\Desktop\movie_data\tags.csv")
df_bk4=df4.copy()
df4.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
merged_data = pd.merge(df1, df2, on = "movieId")

# %%
md = pd.merge(merged_data,df3,on = "movieId")

# %%
md1 = pd.merge(md,df4,on = "movieId")

# %%
md1
# Out:
#         movieId   imdbId    tmdbId                           title  \
# 0             1   114709     862.0                Toy Story (1995)
# 1             1   114709     862.0                Toy Story (1995)
# 2             1   114709     862.0                Toy Story (1995)
# 3             1   114709     862.0                Toy Story (1995)
# 4             1   114709     862.0                Toy Story (1995)
# ...         ...      ...       ...                             ...
# 233208   187595  3778644  348350.0  Solo: A Star Wars Story (2018)
# 233209   193565  1636780   71172.0       Gintama: The Movie (2010)
# 233210   193565  1636780   71172.0       Gintama: The Movie (2010)
# 233211   193565  1636780   71172.0       Gintama: The Movie (2010)
# 233212   193565  1636780   71172.0       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# ...

# %%
max_value = md1['imdbId'].max()

# %%
desired_movie = '"Sci-Fi"'

filtered_row = md1[md1['title'] == desired_movie]

if not filtered_row.empty:
    # Access values from other columns based on the filtered row
    mid_value = filtered_row['movieId'].iloc[0]

else:
    print(f"No data found for {desired_movie}")
# Out:
# No data found for "Sci-Fi"

# %%
mid_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 mid_value
#
# NameError: name 'mid_value' is not defined
